# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from lightgbm import LGBMClassifier
import optuna
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler

tqdm.pandas()

# %%
#import data
df_train = pd.read_csv('./data/Train_folds.zip')
df_test=  pd.read_csv('./data/Test.zip')
submission = pd.read_csv('./data/SampleSubmission.csv')

# %%
train = df_train.copy()
test = df_test.copy()

cat_cols = [
    # 'user_id',
    'REGION',
    'TENURE',
    # 'MRG',  # constant
    # 'TOP_PACK',  # wtf column
]

num_cols = [
    'MONTANT',
    'FREQUENCE_RECH',
    'REVENUE',
    'ARPU_SEGMENT',
    'FREQUENCE',
    'DATA_VOLUME',
    'ON_NET', 
    'ORANGE',
    'TIGO',
    'ZONE1',
    'ZONE2',
    'REGULARITY',
    'FREQ_TOP_PACK',
]

target = 'CHURN'

mapping = {
    'D 3-6 month': 1,
    'E 6-9 month': 2,
    'F 9-12 month': 3,
    'G 12-15 month': 4,
    'H 15-18 month': 5,
    'I 18-21 month': 6,
    'J 21-24 month': 7,
    'K > 24 month': 8,
}

train['TENURE'] = train['TENURE'].map(mapping) 
test['TENURE'] = test['TENURE'].map(mapping)

train['REGION'] = train['REGION'].fillna('DAKAR')
test['REGION'] = test['REGION'].fillna('DAKAR')

for col in tqdm(num_cols):
    col_mean = train[col].mean()
    train[col] = train[col].fillna(col_mean)
    test[col] = test[col].fillna(col_mean)
    train[col] = np.log1p(train[col])
    test[col] = np.log1p(test[col])
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
churn_by_tenure = pd.read_csv('./data/agg_by_tenure_churn.csv')
d = churn_by_tenure[['TENURE', 'CHURN_mean']].to_dict('list')
d = dict(zip(d['TENURE'], d[f'CHURN_mean']))
train['TENURE_CHURN_mean'] = train.progress_apply(lambda x: d[x['TENURE']], axis=1)
test['TENURE_CHURN_mean'] = test.progress_apply(lambda x: d[x['TENURE']], axis=1)

churn_by_region = pd.read_csv('./data/agg_by_region_churn.csv')
d = churn_by_region[['REGION', 'CHURN_mean']].to_dict('list')
d = dict(zip(d['REGION'], d[f'CHURN_mean']))
train['REGION_CHURN_mean'] = train.progress_apply(lambda x: d[x['REGION']], axis=1)
test['REGION_CHURN_mean'] = test.progress_apply(lambda x: d[x['REGION']], axis=1)
# Out:
#   0%|          | 0/2154048 [00:00<?, ?it/s]
#   0%|          | 0/380127 [00:00<?, ?it/s]
#   0%|          | 0/2154048 [00:00<?, ?it/s]
#   0%|          | 0/380127 [00:00<?, ?it/s]

# %%
useful_cols = [
    'REGION',
    'TENURE',
    # 'MRG',  # constant
    # 'TOP_PACK',  # wtf column
    'MONTANT',
    'FREQUENCE_RECH',
    'REVENUE',
    'ARPU_SEGMENT',
    'FREQUENCE',
    'DATA_VOLUME',
    'ON_NET', 
    'ORANGE',
    'TIGO',
    'ZONE1',
    'ZONE2',
    'REGULARITY',
    'FREQ_TOP_PACK',
    'TENURE_CHURN_mean',
    'REGION_CHURN_mean'
]

final_predictions = []
scores = []

for cat_col in cat_cols:
    encoder = OneHotEncoder(handle_unknown='ignore')
    unique_values = train[cat_col].unique()

    one_hot_encoded_cols = [f'{cat_col}_{i}' for i in range(len(unique_values))]
    
    ohe_df = pd.DataFrame(encoder.fit_transform(train[[cat_col]]).toarray(), columns=one_hot_encoded_cols)
    ohe_df.index = train.index
    train = train.drop(cat_col, axis=1)
    train = pd.concat([train, ohe_df], axis=1)        
    print(f'[{cat_col}] xtrain transformed')

    ohe_df = pd.DataFrame(encoder.transform(test[[cat_col]]).toarray(), columns=one_hot_encoded_cols)
    ohe_df.index = test.index
    test = test.drop(cat_col, axis=1)
    test = pd.concat([test, ohe_df], axis=1)
    print(f'[{cat_col}] xtest transformed')
    
    useful_cols += one_hot_encoded_cols
    useful_cols.remove(cat_col)
    
# scaler = StandardScaler()
# train[num_cols] = scaler.fit_transform(train[num_cols])
# test[num_cols] = scaler.transform(test[num_cols])

final_predictions = []
scores = []

target = 'CHURN'

for fold in tqdm(range(5), 'folds'):
    xtrain = train[train['kfold'] != fold][useful_cols]
    ytrain = train[train['kfold'] != fold][target]
    
    xvalid = train[train['kfold'] == fold][useful_cols]
    yvalid = train[train['kfold'] == fold][target]
    
    xtest = test[useful_cols]

    model = LGBMClassifier(
        n_estimators=1000,
        random_state=42, 
#         **{
#             'learning_rate': 0.057192504267984716,
#             'reg_lambda': 0.2020682138073545,
#             'reg_alpha': 9.291468887449219e-07,
#             'subsample': 0.8824763845186918,
#             'colsample_bytree': 0.7382762785360262,
#             'max_depth': 6
#         }
    )
    model.fit(xtrain, ytrain, early_stopping_rounds=300, eval_set=[(xvalid, yvalid)])
    
    preds_valid = model.predict(xvalid)
    test_preds = model.predict(xtest)
    final_predictions.append(test_preds)
    score = roc_auc_score(yvalid, preds_valid)
    scores.append(score)
    print(fold, score)    

print(np.mean(scores), np.std(scores))

# 0.7696186855892555 0.00043098014634677365 fillna через REGION
# 0.7694106138854746 0.000588962476667447 fillna через TENURE
# 0.7701952731313458 0.0006247026357018513 fillna через mean по колонке
# 0.769901864294696 0.000610047154013374 fillna через mean по колонке & ohe for region
# 0.769901864294696 0.000610047154013374 fillna через mean по колонке & ohe for region + StandardScaler for Tenure (same as prev)
# 0.770010208315598 0.0005090535431930928 fillna через mean по колонке & ohe for region & tenure [private: 0.853185019447002]
# 0.770008209799155 0.0005120012284348264 fillna через mean по колонке & ohe for region & tenure for whole train and test datasets & StScaler on whole ds
# 0.7701761776716778 0.0007820978999800708 fillna через mean по колонке & ohe for region & tenure for whole train and test datasets & StScaler on whole ds + target encoding by reg & ten [private 0.862163874472749]
# 0.7690741534134118 0.0008824035170153271 fillna через mean по колонке & ohe for region & tenure for whole train and test datasets & StScaler on whole ds + target encoding by reg & ten + изменил фолды (!= и ==)
# 0.7690825678568933 0.0008789684650258934  fillna через mean по колонке & ohe for region & tenure for whole train and test datasets & StScaler on whole ds + target encoding by reg & ten + изменил фолды (!= и ==)
# 0.7698245780943753 0.000724931679586648 lgb - fillna через mean по колонке & ohe for region & tenure for whole train and test datasets & StScaler on whole ds + target encoding by reg & ten + изменил фолды (!= и ==)
# 0.7694104784482177 0.0013440865822247955 lgb - fillna через mean по колонке & ohe for region & tenure for whole train and test datasets & StScaler on whole ds + target encoding by reg & ten + изменил фолды (!= и ==) + optuna params [0.760814445393041]
# 0.7696374297117283 0.0010216807303939667 lgb - fillna через mean по колонке & ohe for region & tenure for whole train and test datasets & StScaler on whole ds + target encoding by reg & ten + изменил фолды (!= и ==) + num cols log1
# Out:
# [REGION] xtrain transformed
# [REGION] xtest transformed
# [TENURE] xtrain transformed
# [TENURE] xtest transformed
# folds:   0%|          | 0/5 [00:00<?, ?it/s]
# [1]	valid_0's binary_logloss: 0.443644
# Training until validation scores don't improve for 300 rounds
# [2]	valid_0's binary_logloss: 0.414895
# [3]	valid_0's binary_logloss: 0.39266
# [4]	valid_0's binary_logloss: 0.374827
# [5]	valid_0's binary_logloss: 0.360231
# [6]	valid_0's binary_logloss: 0.34812
# [7]	valid_0's binary_logloss: 0.337935
# [8]	valid_0's binary_logloss: 0.329322
# [9]	valid_0's binary_logloss: 0.321979
# [10]	valid_0's binary_logloss: 0.315719
# [11]	valid_0's binary_logloss: 0.310342
# [12]	valid_0's binary_logloss: 0.305697
# [13]	valid_0's binary_logloss: 0.30169
# [14]	valid_0's binary_logloss: 0.298214
# [15]	valid_0's binary_logloss: 0.295218
# [16]	valid_0's binary_logloss: 0.292608
# [17]	valid_0's binary_logloss: 0.290303
# [18]	valid_0's binary_logloss: 0.288299
# [19]	valid_0's binary_logloss: 0.286557
# [20]	valid_0's binary_logloss: 0.28503
# [21]	valid_0's binary_logloss: 0.283703
# [22]	valid_0's binary_logloss: 0.282533
# [23]	valid_0's binary_logloss: 0.281512
# [24]	valid_0's binary_logloss: 0.280626
# [25]	valid_0's binary_logloss: 0.27984
# [26]	valid_0's binary_logloss: 0.279155
# [27]	valid_0's binary_logloss: 0.278544
# [28]	valid_0's binary_logloss: 0.278007
# [29]	valid_0's binary_logloss: 0.277536
# [30]	valid_0's binary_logloss: 0.277105
# [31]	valid_0's binary_logloss: 0.27672
# [32]	valid_0's binary_logloss: 0.276394
# [33]	valid_0's binary_logloss: 0.276091
# [34]	valid_0's binary_logloss: 0.275826
# [35]	valid_0's binary_logloss: 0.275594
# [36]	valid_0's binary_logloss: 0.275376
# [37]	valid_0's binary_logloss: 0.2752
# [38]	valid_0's binary_logloss: 0.275029
# [39]	valid_0's binary_logloss: 0.274871
# [40]	valid_0's binary_logloss: 0.274738
# [41]	valid_0's binary_logloss: 0.274613
# [42]	valid_0's binary_logloss: 0.274497
# [43]	valid_0's binary_logloss: 0.274397
# [44]	valid_0's binary_logloss: 0.27432
# [45]	valid_0's binary_logloss: 0.27425
# [46]	valid_0's binary_logloss: 0.274183
# [47]	valid_0's binary_logloss: 0.27411
# [48]	valid_0's binary_logloss: 0.274049
# [49]	valid_0's binary_logloss: 0.273991
# [50]	valid_0's binary_logloss: 0.273942
# [51]	valid_0's binary_logloss: 0.273903
# [52]	valid_0's binary_logloss: 0.273874
# [53]	valid_0's binary_logloss: 0.27384
# [54]	valid_0's binary_logloss: 0.273812
# [55]	valid_0's binary_logloss: 0.273779
# [56]	valid_0's binary_logloss: 0.273749
# [57]	valid_0's binary_logloss: 0.27373
# [58]	valid_0's binary_logloss: 0.27371
# [59]	valid_0's binary_logloss: 0.273683
# [60]	valid_0's binary_logloss: 0.273671
# [61]	valid_0's binary_logloss: 0.27365
# [62]	valid_0's binary_logloss: 0.273636
# [63]	valid_0's binary_logloss: 0.273621
# [64]	valid_0's binary_logloss: 0.273607
# [65]	valid_0's binary_logloss: 0.273608
# [66]	valid_0's binary_logloss: 0.273583
# [67]	valid_0's binary_logloss: 0.273583
# [68]	valid_0's binary_logloss: 0.273585
# [69]	valid_0's binary_logloss: 0.273579
# [70]	valid_0's binary_logloss: 0.273566
# [71]	valid_0's binary_logloss: 0.273557
# [72]	valid_0's binary_logloss: 0.273545
# [73]	valid_0's binary_logloss: 0.273538
# [74]	valid_0's binary_logloss: 0.273527
# [75]	valid_0's binary_logloss: 0.273526
# [76]	valid_0's binary_logloss: 0.273525
# [77]	valid_0's binary_logloss: 0.273512
# [78]	valid_0's binary_logloss: 0.27351
# [79]	valid_0's binary_logloss: 0.273501
# [80]	valid_0's binary_logloss: 0.273504
# [81]	valid_0's binary_logloss: 0.273501
# [82]	valid_0's binary_logloss: 0.273497
# [83]	valid_0's binary_logloss: 0.273498
# [84]	valid_0's binary_logloss: 0.273483
# [85]	valid_0's binary_logloss: 0.273487
# [86]	valid_0's binary_logloss: 0.273484
# [87]	valid_0's binary_logloss: 0.27348
# [88]	valid_0's binary_logloss: 0.273464
# [89]	valid_0's binary_logloss: 0.273466
# [90]	valid_0's binary_logloss: 0.273463
# [91]	valid_0's binary_logloss: 0.273459
# [92]	valid_0's binary_logloss: 0.273462
# [93]	valid_0's binary_logloss: 0.273464
# [94]	valid_0's binary_logloss: 0.273459
# [95]	valid_0's binary_logloss: 0.27346
# [96]	valid_0's binary_logloss: 0.27346
# [97]	valid_0's binary_logloss: 0.273456
# [98]	valid_0's binary_logloss: 0.273458
# [99]	valid_0's binary_logloss: 0.273459
# [100]	valid_0's binary_logloss: 0.27345
# [101]	valid_0's binary_logloss: 0.273471
# [102]	valid_0's binary_logloss: 0.273458
# [103]	valid_0's binary_logloss: 0.273458
# [104]	valid_0's binary_logloss: 0.273455
# [105]	valid_0's binary_logloss: 0.273455
# [106]	valid_0's binary_logloss: 0.273456
# [107]	valid_0's binary_logloss: 0.273457
# [108]	valid_0's binary_logloss: 0.273458
# [109]	valid_0's binary_logloss: 0.27345
# [110]	valid_0's binary_logloss: 0.273448
# [111]	valid_0's binary_logloss: 0.273443
# [112]	valid_0's binary_logloss: 0.273443
# [113]	valid_0's binary_logloss: 0.273445
# [114]	valid_0's binary_logloss: 0.273436
# [115]	valid_0's binary_logloss: 0.273571
# [116]	valid_0's binary_logloss: 0.273572
# [117]	valid_0's binary_logloss: 0.273571
# [118]	valid_0's binary_logloss: 0.27357
# [119]	valid_0's binary_logloss: 0.273599
# [120]	valid_0's binary_logloss: 0.273593
# [121]	valid_0's binary_logloss: 0.273592
# [122]	valid_0's binary_logloss: 0.273691
# [123]	valid_0's binary_logloss: 0.274267
# [124]	valid_0's binary_logloss: 0.273778
# [125]	valid_0's binary_logloss: 0.273581
# [126]	valid_0's binary_logloss: 0.273581
# [127]	valid_0's binary_logloss: 0.273802
# [128]	valid_0's binary_logloss: 0.273892
# [129]	valid_0's binary_logloss: 0.274652
# [130]	valid_0's binary_logloss: 0.273808
# [131]	valid_0's binary_logloss: 0.274191
# [132]	valid_0's binary_logloss: 0.273948
# [133]	valid_0's binary_logloss: 0.273637
# [134]	valid_0's binary_logloss: 0.273621
# [135]	valid_0's binary_logloss: 0.273965
# [136]	valid_0's binary_logloss: 0.275189
# [137]	valid_0's binary_logloss: 0.274168
# [138]	valid_0's binary_logloss: 0.273866
# [139]	valid_0's binary_logloss: 0.274552
# [140]	valid_0's binary_logloss: 0.273959
# [141]	valid_0's binary_logloss: 0.274397
# [142]	valid_0's binary_logloss: 0.274099
# [143]	valid_0's binary_logloss: 0.274642
# [144]	valid_0's binary_logloss: 0.273995
# [145]	valid_0's binary_logloss: 0.274043
# [146]	valid_0's binary_logloss: 0.275215
# [147]	valid_0's binary_logloss: 0.274418
# [148]	valid_0's binary_logloss: 0.274208
# [149]	valid_0's binary_logloss: 0.275366
# [150]	valid_0's binary_logloss: 0.275738
# [151]	valid_0's binary_logloss: 0.276355
# [152]	valid_0's binary_logloss: 0.275319
# [153]	valid_0's binary_logloss: 0.276571
# [154]	valid_0's binary_logloss: 0.276006
# [155]	valid_0's binary_logloss: 0.276482
# [156]	valid_0's binary_logloss: 0.275811
# [157]	valid_0's binary_logloss: 0.277093
# [158]	valid_0's binary_logloss: 0.276808
# [159]	valid_0's binary_logloss: 0.276853
# [160]	valid_0's binary_logloss: 0.2762
# [161]	valid_0's binary_logloss: 0.276195
# [162]	valid_0's binary_logloss: 0.276187
# [163]	valid_0's binary_logloss: 0.276206
# [164]	valid_0's binary_logloss: 0.277323
# [165]	valid_0's binary_logloss: 0.276199
# [166]	valid_0's binary_logloss: 0.276201
# [167]	valid_0's binary_logloss: 0.2762
# [168]	valid_0's binary_logloss: 0.276201
# [169]	valid_0's binary_logloss: 0.276198
# [170]	valid_0's binary_logloss: 0.27892
# [171]	valid_0's binary_logloss: 0.276664
# [172]	valid_0's binary_logloss: 0.276434
# [173]	valid_0's binary_logloss: 0.276433
# [174]	valid_0's binary_logloss: 0.276432
# [175]	valid_0's binary_logloss: 0.276411
# [176]	valid_0's binary_logloss: 0.276334
# [177]	valid_0's binary_logloss: 0.276332
# [178]	valid_0's binary_logloss: 0.276331
# [179]	valid_0's binary_logloss: 0.276326
# [180]	valid_0's binary_logloss: 0.276386
# [181]	valid_0's binary_logloss: 0.276353
# [182]	valid_0's binary_logloss: 0.276353
# [183]	valid_0's binary_logloss: 0.276375
# [184]	valid_0's binary_logloss: 0.276614
# [185]	valid_0's binary_logloss: 0.276455
# [186]	valid_0's binary_logloss: 0.279439
# [187]	valid_0's binary_logloss: 0.285055
# [188]	valid_0's binary_logloss: 0.281363
# [189]	valid_0's binary_logloss: 0.276938
# [190]	valid_0's binary_logloss: 0.281447
# [191]	valid_0's binary_logloss: 0.279996
# [192]	valid_0's binary_logloss: 0.277047
# [193]	valid_0's binary_logloss: 0.280262
# [194]	valid_0's binary_logloss: 0.278304
# [195]	valid_0's binary_logloss: 0.277428
# [196]	valid_0's binary_logloss: 0.276536
# [197]	valid_0's binary_logloss: 0.283148
# [198]	valid_0's binary_logloss: 0.278008
# [199]	valid_0's binary_logloss: 0.276338
# [200]	valid_0's binary_logloss: 0.278052
# [201]	valid_0's binary_logloss: 0.275969
# [202]	valid_0's binary_logloss: 0.279801
# [203]	valid_0's binary_logloss: 0.278696
# [204]	valid_0's binary_logloss: 0.277976
# [205]	valid_0's binary_logloss: 0.276641
# [206]	valid_0's binary_logloss: 0.276325
# [207]	valid_0's binary_logloss: 0.276164
# [208]	valid_0's binary_logloss: 0.276197
# [209]	valid_0's binary_logloss: 0.276194
# [210]	valid_0's binary_logloss: 0.276192
# [211]	valid_0's binary_logloss: 0.276189
# [212]	valid_0's binary_logloss: 0.276748
# [213]	valid_0's binary_logloss: 0.276426
# [214]	valid_0's binary_logloss: 0.27635
# [215]	valid_0's binary_logloss: 0.276345
# [216]	valid_0's binary_logloss: 0.27634
# [217]	valid_0's binary_logloss: 0.276338
# [218]	valid_0's binary_logloss: 0.276338
# [219]	valid_0's binary_logloss: 0.276333
# [220]	valid_0's binary_logloss: 0.276328
# [221]	valid_0's binary_logloss: 0.276326
# [222]	valid_0's binary_logloss: 0.276324
# [223]	valid_0's binary_logloss: 0.276323
# [224]	valid_0's binary_logloss: 0.276323
# [225]	valid_0's binary_logloss: 0.276323
# [226]	valid_0's binary_logloss: 0.278803
# [227]	valid_0's binary_logloss: 0.276702
# [228]	valid_0's binary_logloss: 0.276366
# [229]	valid_0's binary_logloss: 0.276316
# [230]	valid_0's binary_logloss: 0.278488
# [231]	valid_0's binary_logloss: 0.277755
# [232]	valid_0's binary_logloss: 0.277513
# [233]	valid_0's binary_logloss: 0.277369
# [234]	valid_0's binary_logloss: 0.277132
# [235]	valid_0's binary_logloss: 0.277338
# [236]	valid_0's binary_logloss: 0.277584
# [237]	valid_0's binary_logloss: 0.277252
# [238]	valid_0's binary_logloss: 0.277252
# [239]	valid_0's binary_logloss: 0.277251
# [240]	valid_0's binary_logloss: 0.277249
# [241]	valid_0's binary_logloss: 0.277247
# [242]	valid_0's binary_logloss: 0.277239
# [243]	valid_0's binary_logloss: 0.277238
# [244]	valid_0's binary_logloss: 0.277191
# [245]	valid_0's binary_logloss: 0.277192
# [246]	valid_0's binary_logloss: 0.277193
# [247]	valid_0's binary_logloss: 0.277194
# [248]	valid_0's binary_logloss: 0.279658
# [249]	valid_0's binary_logloss: 0.278077
# [250]	valid_0's binary_logloss: 0.278958
# [251]	valid_0's binary_logloss: 0.27865
# [252]	valid_0's binary_logloss: 0.289286
# [253]	valid_0's binary_logloss: 0.279001
# [254]	valid_0's binary_logloss: 0.279927
# [255]	valid_0's binary_logloss: 0.277634
# [256]	valid_0's binary_logloss: 0.277627
# [257]	valid_0's binary_logloss: 0.277622
# [258]	valid_0's binary_logloss: 0.277625
# [259]	valid_0's binary_logloss: 0.277626
# [260]	valid_0's binary_logloss: 0.277666
# [261]	valid_0's binary_logloss: 0.277644
# [262]	valid_0's binary_logloss: 0.277644
# [263]	valid_0's binary_logloss: 0.277642
# [264]	valid_0's binary_logloss: 0.277636
# [265]	valid_0's binary_logloss: 0.277634
# [266]	valid_0's binary_logloss: 0.277948
# [267]	valid_0's binary_logloss: 0.277711
# [268]	valid_0's binary_logloss: 0.279515
# [269]	valid_0's binary_logloss: 0.277915
# [270]	valid_0's binary_logloss: 0.280215
# [271]	valid_0's binary_logloss: 0.280206
# [272]	valid_0's binary_logloss: 0.27853
# [273]	valid_0's binary_logloss: 0.278162
# [274]	valid_0's binary_logloss: 0.278093
# [275]	valid_0's binary_logloss: 0.278096
# [276]	valid_0's binary_logloss: 0.28018
# [277]	valid_0's binary_logloss: 0.278555
# [278]	valid_0's binary_logloss: 0.278344
# [279]	valid_0's binary_logloss: 0.278344
# [280]	valid_0's binary_logloss: 0.278342
# [281]	valid_0's binary_logloss: 0.278339
# [282]	valid_0's binary_logloss: 0.27834
# [283]	valid_0's binary_logloss: 0.278335
# [284]	valid_0's binary_logloss: 0.278332
# [285]	valid_0's binary_logloss: 0.279825
# [286]	valid_0's binary_logloss: 0.278986
# [287]	valid_0's binary_logloss: 0.282823
# [288]	valid_0's binary_logloss: 0.279043
# [289]	valid_0's binary_logloss: 0.27916
# [290]	valid_0's binary_logloss: 0.279047
# [291]	valid_0's binary_logloss: 0.293789
# [292]	valid_0's binary_logloss: 0.280331
# [293]	valid_0's binary_logloss: 0.279229
# [294]	valid_0's binary_logloss: 0.290378
# [295]	valid_0's binary_logloss: 0.280344
# [296]	valid_0's binary_logloss: 0.282503
# [297]	valid_0's binary_logloss: 0.279377
# [298]	valid_0's binary_logloss: 0.279377
# [299]	valid_0's binary_logloss: 0.279375
# [300]	valid_0's binary_logloss: 0.279376
# [301]	valid_0's binary_logloss: 0.279376
# [302]	valid_0's binary_logloss: 0.283338
# [303]	valid_0's binary_logloss: 0.280311
# [304]	valid_0's binary_logloss: 0.279776
# [305]	valid_0's binary_logloss: 0.279773
# [306]	valid_0's binary_logloss: 0.279771
# [307]	valid_0's binary_logloss: 0.279988
# [308]	valid_0's binary_logloss: 0.281451
# [309]	valid_0's binary_logloss: 0.280344
# [310]	valid_0's binary_logloss: 0.28033
# [311]	valid_0's binary_logloss: 0.280349
# [312]	valid_0's binary_logloss: 0.280649
# [313]	valid_0's binary_logloss: 0.280618
# [314]	valid_0's binary_logloss: 0.287485
# [315]	valid_0's binary_logloss: 0.281053
# [316]	valid_0's binary_logloss: 0.280666
# [317]	valid_0's binary_logloss: 0.280665
# [318]	valid_0's binary_logloss: 0.28256
# [319]	valid_0's binary_logloss: 0.280736
# [320]	valid_0's binary_logloss: 0.28461
# [321]	valid_0's binary_logloss: 0.283481
# [322]	valid_0's binary_logloss: 0.281729
# [323]	valid_0's binary_logloss: 0.284139
# [324]	valid_0's binary_logloss: 0.283186
# [325]	valid_0's binary_logloss: 0.280856
# [326]	valid_0's binary_logloss: 0.280862
# [327]	valid_0's binary_logloss: 0.2811
# [328]	valid_0's binary_logloss: 0.280859
# [329]	valid_0's binary_logloss: 0.280859
# [330]	valid_0's binary_logloss: 0.28086
# [331]	valid_0's binary_logloss: 0.280858
# [332]	valid_0's binary_logloss: 0.281023
# [333]	valid_0's binary_logloss: 0.287035
# [334]	valid_0's binary_logloss: 0.281848
# [335]	valid_0's binary_logloss: 0.281044
# [336]	valid_0's binary_logloss: 0.280908
# [337]	valid_0's binary_logloss: 0.281193
# [338]	valid_0's binary_logloss: 0.281023
# [339]	valid_0's binary_logloss: 0.281242
# [340]	valid_0's binary_logloss: 0.281076
# [341]	valid_0's binary_logloss: 0.280912
# [342]	valid_0's binary_logloss: 0.280911
# [343]	valid_0's binary_logloss: 0.280984
# [344]	valid_0's binary_logloss: 0.281393
# [345]	valid_0's binary_logloss: 0.281039
# [346]	valid_0's binary_logloss: 0.28083
# [347]	valid_0's binary_logloss: 0.280793
# [348]	valid_0's binary_logloss: 0.280791
# [349]	valid_0's binary_logloss: 0.281411
# [350]	valid_0's binary_logloss: 0.280804
# [351]	valid_0's binary_logloss: 0.28077
# [352]	valid_0's binary_logloss: 0.280765
# [353]	valid_0's binary_logloss: 0.280841
# [354]	valid_0's binary_logloss: 0.280888
# [355]	valid_0's binary_logloss: 0.280813
# [356]	valid_0's binary_logloss: 0.281134
# [357]	valid_0's binary_logloss: 0.280828
# [358]	valid_0's binary_logloss: 0.281701
# [359]	valid_0's binary_logloss: 0.281261
# [360]	valid_0's binary_logloss: 0.280964
# [361]	valid_0's binary_logloss: 0.280893
# [362]	valid_0's binary_logloss: 0.280874
# [363]	valid_0's binary_logloss: 0.280869
# [364]	valid_0's binary_logloss: 0.281668
# [365]	valid_0's binary_logloss: 0.281012
# [366]	valid_0's binary_logloss: 0.280926
# [367]	valid_0's binary_logloss: 0.280925
# [368]	valid_0's binary_logloss: 0.28092
# [369]	valid_0's binary_logloss: 0.28095
# [370]	valid_0's binary_logloss: 0.282771
# [371]	valid_0's binary_logloss: 0.281009
# [372]	valid_0's binary_logloss: 0.289885
# [373]	valid_0's binary_logloss: 0.286836
# [374]	valid_0's binary_logloss: 0.284445
# [375]	valid_0's binary_logloss: 0.282315
# [376]	valid_0's binary_logloss: 0.281652
# [377]	valid_0's binary_logloss: 0.281947
# [378]	valid_0's binary_logloss: 0.281626
# [379]	valid_0's binary_logloss: 0.282264
# [380]	valid_0's binary_logloss: 0.282077
# [381]	valid_0's binary_logloss: 0.283002
# [382]	valid_0's binary_logloss: 0.282021
# [383]	valid_0's binary_logloss: 0.28677
# [384]	valid_0's binary_logloss: 0.282184
# [385]	valid_0's binary_logloss: 0.284762
# [386]	valid_0's binary_logloss: 0.2846
# [387]	valid_0's binary_logloss: 0.284703
# [388]	valid_0's binary_logloss: 0.286596
# [389]	valid_0's binary_logloss: 0.284226
# [390]	valid_0's binary_logloss: 0.288032
# [391]	valid_0's binary_logloss: 0.283605
# [392]	valid_0's binary_logloss: 0.28421
# [393]	valid_0's binary_logloss: 0.283507
# [394]	valid_0's binary_logloss: 0.28497
# [395]	valid_0's binary_logloss: 0.284373
# [396]	valid_0's binary_logloss: 0.283592
# [397]	valid_0's binary_logloss: 0.283544
# [398]	valid_0's binary_logloss: 0.283563
# [399]	valid_0's binary_logloss: 0.28356
# [400]	valid_0's binary_logloss: 0.285387
# [401]	valid_0's binary_logloss: 0.284465
# [402]	valid_0's binary_logloss: 0.286765
# [403]	valid_0's binary_logloss: 0.283967
# [404]	valid_0's binary_logloss: 0.284062
# [405]	valid_0's binary_logloss: 0.285019
# [406]	valid_0's binary_logloss: 0.285011
# [407]	valid_0's binary_logloss: 0.28632
# [408]	valid_0's binary_logloss: 0.284043
# [409]	valid_0's binary_logloss: 0.284044
# [410]	valid_0's binary_logloss: 0.284664
# [411]	valid_0's binary_logloss: 0.283832
# [412]	valid_0's binary_logloss: 0.285879
# [413]	valid_0's binary_logloss: 0.284393
# [414]	valid_0's binary_logloss: 0.28616
# Early stopping, best iteration is:
# [114]	valid_0's binary_logloss: 0.273436
# 0 0.7697445403580361
# [1]	valid_0's binary_logloss: 0.443328
# Training until validation scores don't improve for 300 rounds
# [2]	valid_0's binary_logloss: 0.414598
# [3]	valid_0's binary_logloss: 0.392349
# [4]	valid_0's binary_logloss: 0.374502
# [5]	valid_0's binary_logloss: 0.359872
# [6]	valid_0's binary_logloss: 0.34774
# [7]	valid_0's binary_logloss: 0.337525
# [8]	valid_0's binary_logloss: 0.328914
# [9]	valid_0's binary_logloss: 0.32154
# [10]	valid_0's binary_logloss: 0.315237
# [11]	valid_0's binary_logloss: 0.309852
# [12]	valid_0's binary_logloss: 0.305199
# [13]	valid_0's binary_logloss: 0.301173
# [14]	valid_0's binary_logloss: 0.297675
# [15]	valid_0's binary_logloss: 0.294658
# [16]	valid_0's binary_logloss: 0.292029
# [17]	valid_0's binary_logloss: 0.289705
# [18]	valid_0's binary_logloss: 0.287676
# [19]	valid_0's binary_logloss: 0.285917
# [20]	valid_0's binary_logloss: 0.284373
# [21]	valid_0's binary_logloss: 0.283029
# [22]	valid_0's binary_logloss: 0.281851
# [23]	valid_0's binary_logloss: 0.280827
# [24]	valid_0's binary_logloss: 0.279932
# [25]	valid_0's binary_logloss: 0.279134
# [26]	valid_0's binary_logloss: 0.278438
# [27]	valid_0's binary_logloss: 0.2778
# [28]	valid_0's binary_logloss: 0.277254
# [29]	valid_0's binary_logloss: 0.276763
# [30]	valid_0's binary_logloss: 0.27632
# [31]	valid_0's binary_logloss: 0.275945
# [32]	valid_0's binary_logloss: 0.275616
# [33]	valid_0's binary_logloss: 0.275318
# [34]	valid_0's binary_logloss: 0.27504
# [35]	valid_0's binary_logloss: 0.274807
# [36]	valid_0's binary_logloss: 0.274591
# [37]	valid_0's binary_logloss: 0.274386
# [38]	valid_0's binary_logloss: 0.27419
# [39]	valid_0's binary_logloss: 0.27403
# [40]	valid_0's binary_logloss: 0.273888
# [41]	valid_0's binary_logloss: 0.273768
# [42]	valid_0's binary_logloss: 0.273648
# [43]	valid_0's binary_logloss: 0.273543
# [44]	valid_0's binary_logloss: 0.27345
# [45]	valid_0's binary_logloss: 0.273364
# [46]	valid_0's binary_logloss: 0.273281
# [47]	valid_0's binary_logloss: 0.273207
# [48]	valid_0's binary_logloss: 0.273141
# [49]	valid_0's binary_logloss: 0.273078
# [50]	valid_0's binary_logloss: 0.273026
# [51]	valid_0's binary_logloss: 0.27298
# [52]	valid_0's binary_logloss: 0.272944
# [53]	valid_0's binary_logloss: 0.272914
# [54]	valid_0's binary_logloss: 0.272875
# [55]	valid_0's binary_logloss: 0.272841
# [56]	valid_0's binary_logloss: 0.272808
# [57]	valid_0's binary_logloss: 0.272845
# [58]	valid_0's binary_logloss: 0.272769
# [59]	valid_0's binary_logloss: 0.272742
# [60]	valid_0's binary_logloss: 0.272729
# [61]	valid_0's binary_logloss: 0.2727
# [62]	valid_0's binary_logloss: 0.272678
# [63]	valid_0's binary_logloss: 0.272659
# [64]	valid_0's binary_logloss: 0.27263
# [65]	valid_0's binary_logloss: 0.272612
# [66]	valid_0's binary_logloss: 0.272598
# [67]	valid_0's binary_logloss: 0.272586
# [68]	valid_0's binary_logloss: 0.272568
# [69]	valid_0's binary_logloss: 0.272566
# [70]	valid_0's binary_logloss: 0.272557
# [71]	valid_0's binary_logloss: 0.272562
# [72]	valid_0's binary_logloss: 0.272554
# [73]	valid_0's binary_logloss: 0.27255
# [74]	valid_0's binary_logloss: 0.272532
# [75]	valid_0's binary_logloss: 0.272529
# [76]	valid_0's binary_logloss: 0.272516
# [77]	valid_0's binary_logloss: 0.272516
# [78]	valid_0's binary_logloss: 0.272507
# [79]	valid_0's binary_logloss: 0.272506
# [80]	valid_0's binary_logloss: 0.272496
# [81]	valid_0's binary_logloss: 0.272495
# [82]	valid_0's binary_logloss: 0.272492
# [83]	valid_0's binary_logloss: 0.27249
# [84]	valid_0's binary_logloss: 0.27249
# [85]	valid_0's binary_logloss: 0.272488
# [86]	valid_0's binary_logloss: 0.272536
# [87]	valid_0's binary_logloss: 0.272507
# [88]	valid_0's binary_logloss: 0.2725
# [89]	valid_0's binary_logloss: 0.272498
# [90]	valid_0's binary_logloss: 0.2725
# [91]	valid_0's binary_logloss: 0.27251
# [92]	valid_0's binary_logloss: 0.272513
# [93]	valid_0's binary_logloss: 0.272511
# [94]	valid_0's binary_logloss: 0.272505
# [95]	valid_0's binary_logloss: 0.272506
# [96]	valid_0's binary_logloss: 0.272502
# [97]	valid_0's binary_logloss: 0.272501
# [98]	valid_0's binary_logloss: 0.272477
# [99]	valid_0's binary_logloss: 0.272506
# [100]	valid_0's binary_logloss: 0.272505
# [101]	valid_0's binary_logloss: 0.272483
# [102]	valid_0's binary_logloss: 0.272489
# [103]	valid_0's binary_logloss: 0.272489
# [104]	valid_0's binary_logloss: 0.272478
# [105]	valid_0's binary_logloss: 0.272477
# [106]	valid_0's binary_logloss: 0.272476
# [107]	valid_0's binary_logloss: 0.272477
# [108]	valid_0's binary_logloss: 0.272474
# [109]	valid_0's binary_logloss: 0.272477
# [110]	valid_0's binary_logloss: 0.272477
# [111]	valid_0's binary_logloss: 0.272477
# [112]	valid_0's binary_logloss: 0.272477
# [113]	valid_0's binary_logloss: 0.272476
# [114]	valid_0's binary_logloss: 0.272474
# [115]	valid_0's binary_logloss: 0.272474
# [116]	valid_0's binary_logloss: 0.272478
# [117]	valid_0's binary_logloss: 0.27248
# [118]	valid_0's binary_logloss: 0.272547
# [119]	valid_0's binary_logloss: 0.272538
# [120]	valid_0's binary_logloss: 0.272507
# [121]	valid_0's binary_logloss: 0.272505
# [122]	valid_0's binary_logloss: 0.272506
# [123]	valid_0's binary_logloss: 0.272502
# [124]	valid_0's binary_logloss: 0.272501
# [125]	valid_0's binary_logloss: 0.272499
# [126]	valid_0's binary_logloss: 0.2725
# [127]	valid_0's binary_logloss: 0.272501
# [128]	valid_0's binary_logloss: 0.272498
# [129]	valid_0's binary_logloss: 0.272497
# [130]	valid_0's binary_logloss: 0.272498
# [131]	valid_0's binary_logloss: 0.272499
# [132]	valid_0's binary_logloss: 0.272511
# [133]	valid_0's binary_logloss: 0.272514
# [134]	valid_0's binary_logloss: 0.272504
# [135]	valid_0's binary_logloss: 0.272508
# [136]	valid_0's binary_logloss: 0.27251
# [137]	valid_0's binary_logloss: 0.272505
# [138]	valid_0's binary_logloss: 0.272507
# [139]	valid_0's binary_logloss: 0.272508
# [140]	valid_0's binary_logloss: 0.272674
# [141]	valid_0's binary_logloss: 0.272614
# [142]	valid_0's binary_logloss: 0.272525
# [143]	valid_0's binary_logloss: 0.272528
# [144]	valid_0's binary_logloss: 0.272527
# [145]	valid_0's binary_logloss: 0.272523
# [146]	valid_0's binary_logloss: 0.272527
# [147]	valid_0's binary_logloss: 0.272541
# [148]	valid_0's binary_logloss: 0.273032
# [149]	valid_0's binary_logloss: 0.272638
# [150]	valid_0's binary_logloss: 0.272635
# [151]	valid_0's binary_logloss: 0.272632
# [152]	valid_0's binary_logloss: 0.272637
# [153]	valid_0's binary_logloss: 0.272637
# [154]	valid_0's binary_logloss: 0.272856
# [155]	valid_0's binary_logloss: 0.272655
# [156]	valid_0's binary_logloss: 0.272654
# [157]	valid_0's binary_logloss: 0.272655
# [158]	valid_0's binary_logloss: 0.272654
# [159]	valid_0's binary_logloss: 0.272653
# [160]	valid_0's binary_logloss: 0.272654
# [161]	valid_0's binary_logloss: 0.272991
# [162]	valid_0's binary_logloss: 0.273049
# [163]	valid_0's binary_logloss: 0.273084
# [164]	valid_0's binary_logloss: 0.272697
# [165]	valid_0's binary_logloss: 0.272699
# [166]	valid_0's binary_logloss: 0.2727
# [167]	valid_0's binary_logloss: 0.272693
# [168]	valid_0's binary_logloss: 0.272707
# [169]	valid_0's binary_logloss: 0.273186
# [170]	valid_0's binary_logloss: 0.272706
# [171]	valid_0's binary_logloss: 0.272702
# [172]	valid_0's binary_logloss: 0.272904
# [173]	valid_0's binary_logloss: 0.272945
# [174]	valid_0's binary_logloss: 0.273189
# [175]	valid_0's binary_logloss: 0.273329
# [176]	valid_0's binary_logloss: 0.273486
# [177]	valid_0's binary_logloss: 0.274046
# [178]	valid_0's binary_logloss: 0.273243
# [179]	valid_0's binary_logloss: 0.273217
# [180]	valid_0's binary_logloss: 0.273183
# [181]	valid_0's binary_logloss: 0.273178
# [182]	valid_0's binary_logloss: 0.273177
# [183]	valid_0's binary_logloss: 0.27502
# [184]	valid_0's binary_logloss: 0.273504
# [185]	valid_0's binary_logloss: 0.27353
# [186]	valid_0's binary_logloss: 0.273404
# [187]	valid_0's binary_logloss: 0.273566
# [188]	valid_0's binary_logloss: 0.273528
# [189]	valid_0's binary_logloss: 0.273526
# [190]	valid_0's binary_logloss: 0.273526
# [191]	valid_0's binary_logloss: 0.273522
# [192]	valid_0's binary_logloss: 0.273516
# [193]	valid_0's binary_logloss: 0.273488
# [194]	valid_0's binary_logloss: 0.273486
# [195]	valid_0's binary_logloss: 0.273578
# [196]	valid_0's binary_logloss: 0.274951
# [197]	valid_0's binary_logloss: 0.273947
# [198]	valid_0's binary_logloss: 0.273938
# [199]	valid_0's binary_logloss: 0.274219
# [200]	valid_0's binary_logloss: 0.274187
# [201]	valid_0's binary_logloss: 0.276368
# [202]	valid_0's binary_logloss: 0.274789
# [203]	valid_0's binary_logloss: 0.275131
# [204]	valid_0's binary_logloss: 0.275033
# [205]	valid_0's binary_logloss: 0.275038
# [206]	valid_0's binary_logloss: 0.274851
# [207]	valid_0's binary_logloss: 0.274848
# [208]	valid_0's binary_logloss: 0.274842
# [209]	valid_0's binary_logloss: 0.276116
# [210]	valid_0's binary_logloss: 0.276203
# [211]	valid_0's binary_logloss: 0.275931
# [212]	valid_0's binary_logloss: 0.27639
# [213]	valid_0's binary_logloss: 0.275764
# [214]	valid_0's binary_logloss: 0.275686
# [215]	valid_0's binary_logloss: 0.275667
# [216]	valid_0's binary_logloss: 0.276696
# [217]	valid_0's binary_logloss: 0.275973
# [218]	valid_0's binary_logloss: 0.276044
# [219]	valid_0's binary_logloss: 0.27596
# [220]	valid_0's binary_logloss: 0.276088
# [221]	valid_0's binary_logloss: 0.27626
# [222]	valid_0's binary_logloss: 0.276157
# [223]	valid_0's binary_logloss: 0.278041
# [224]	valid_0's binary_logloss: 0.276115
# [225]	valid_0's binary_logloss: 0.276051
# [226]	valid_0's binary_logloss: 0.276051
# [227]	valid_0's binary_logloss: 0.276048
# [228]	valid_0's binary_logloss: 0.276048
# [229]	valid_0's binary_logloss: 0.276041
# [230]	valid_0's binary_logloss: 0.276041
# [231]	valid_0's binary_logloss: 0.276044
# [232]	valid_0's binary_logloss: 0.276839
# [233]	valid_0's binary_logloss: 0.276117
# [234]	valid_0's binary_logloss: 0.276122
# [235]	valid_0's binary_logloss: 0.276416
# [236]	valid_0's binary_logloss: 0.276238
# [237]	valid_0's binary_logloss: 0.276239
# [238]	valid_0's binary_logloss: 0.27624
# [239]	valid_0's binary_logloss: 0.278305
# [240]	valid_0's binary_logloss: 0.276996
# [241]	valid_0's binary_logloss: 0.276963
# [242]	valid_0's binary_logloss: 0.277937
# [243]	valid_0's binary_logloss: 0.276814
# [244]	valid_0's binary_logloss: 0.276726
# [245]	valid_0's binary_logloss: 0.27729
# [246]	valid_0's binary_logloss: 0.277291
# [247]	valid_0's binary_logloss: 0.277981
# [248]	valid_0's binary_logloss: 0.278209
# [249]	valid_0's binary_logloss: 0.277522
# [250]	valid_0's binary_logloss: 0.278195
# [251]	valid_0's binary_logloss: 0.277955
# [252]	valid_0's binary_logloss: 0.277394
# [253]	valid_0's binary_logloss: 0.277467
# [254]	valid_0's binary_logloss: 0.278448
# [255]	valid_0's binary_logloss: 0.277689
# [256]	valid_0's binary_logloss: 0.278406
# [257]	valid_0's binary_logloss: 0.277622
# [258]	valid_0's binary_logloss: 0.278025
# [259]	valid_0's binary_logloss: 0.277775
# [260]	valid_0's binary_logloss: 0.279129
# [261]	valid_0's binary_logloss: 0.280881
# [262]	valid_0's binary_logloss: 0.277681
# [263]	valid_0's binary_logloss: 0.279996
# [264]	valid_0's binary_logloss: 0.277965
# [265]	valid_0's binary_logloss: 0.277886
# [266]	valid_0's binary_logloss: 0.277887
# [267]	valid_0's binary_logloss: 0.277884
# [268]	valid_0's binary_logloss: 0.277879
# [269]	valid_0's binary_logloss: 0.277873
# [270]	valid_0's binary_logloss: 0.277658
# [271]	valid_0's binary_logloss: 0.277658
# [272]	valid_0's binary_logloss: 0.27766
# [273]	valid_0's binary_logloss: 0.277662
# [274]	valid_0's binary_logloss: 0.277653
# [275]	valid_0's binary_logloss: 0.27765
# [276]	valid_0's binary_logloss: 0.277651
# [277]	valid_0's binary_logloss: 0.278288
# [278]	valid_0's binary_logloss: 0.277647
# [279]	valid_0's binary_logloss: 0.277612
# [280]	valid_0's binary_logloss: 0.277614
# [281]	valid_0's binary_logloss: 0.277615
# [282]	valid_0's binary_logloss: 0.277618
# [283]	valid_0's binary_logloss: 0.277621
# [284]	valid_0's binary_logloss: 0.277624
# [285]	valid_0's binary_logloss: 0.277616
# [286]	valid_0's binary_logloss: 0.277618
# [287]	valid_0's binary_logloss: 0.277619
# [288]	valid_0's binary_logloss: 0.27762
# [289]	valid_0's binary_logloss: 0.278492
# [290]	valid_0's binary_logloss: 0.27737
# [291]	valid_0's binary_logloss: 0.27737
# [292]	valid_0's binary_logloss: 0.277369
# [293]	valid_0's binary_logloss: 0.277367
# [294]	valid_0's binary_logloss: 0.277361
# [295]	valid_0's binary_logloss: 0.277354
# [296]	valid_0's binary_logloss: 0.277354
# [297]	valid_0's binary_logloss: 0.277356
# [298]	valid_0's binary_logloss: 0.277503
# [299]	valid_0's binary_logloss: 0.277489
# [300]	valid_0's binary_logloss: 0.27801
# [301]	valid_0's binary_logloss: 0.277638
# [302]	valid_0's binary_logloss: 0.278069
# [303]	valid_0's binary_logloss: 0.27768
# [304]	valid_0's binary_logloss: 0.277597
# [305]	valid_0's binary_logloss: 0.278968
# [306]	valid_0's binary_logloss: 0.278158
# [307]	valid_0's binary_logloss: 0.278
# [308]	valid_0's binary_logloss: 0.277443
# [309]	valid_0's binary_logloss: 0.277846
# [310]	valid_0's binary_logloss: 0.278011
# [311]	valid_0's binary_logloss: 0.27801
# [312]	valid_0's binary_logloss: 0.278007
# [313]	valid_0's binary_logloss: 0.278007
# [314]	valid_0's binary_logloss: 0.278246
# [315]	valid_0's binary_logloss: 0.277991
# [316]	valid_0's binary_logloss: 0.27796
# [317]	valid_0's binary_logloss: 0.277929
# [318]	valid_0's binary_logloss: 0.277831
# [319]	valid_0's binary_logloss: 0.277838
# [320]	valid_0's binary_logloss: 0.277836
# [321]	valid_0's binary_logloss: 0.277825
# [322]	valid_0's binary_logloss: 0.277823
# [323]	valid_0's binary_logloss: 0.277825
# [324]	valid_0's binary_logloss: 0.27783
# [325]	valid_0's binary_logloss: 0.277831
# [326]	valid_0's binary_logloss: 0.277834
# [327]	valid_0's binary_logloss: 0.277834
# [328]	valid_0's binary_logloss: 0.277838
# [329]	valid_0's binary_logloss: 0.27802
# [330]	valid_0's binary_logloss: 0.282509
# [331]	valid_0's binary_logloss: 0.280601
# [332]	valid_0's binary_logloss: 0.279883
# [333]	valid_0's binary_logloss: 0.278983
# [334]	valid_0's binary_logloss: 0.278338
# [335]	valid_0's binary_logloss: 0.278329
# [336]	valid_0's binary_logloss: 0.278331
# [337]	valid_0's binary_logloss: 0.27831
# [338]	valid_0's binary_logloss: 0.278309
# [339]	valid_0's binary_logloss: 0.2783
# [340]	valid_0's binary_logloss: 0.278305
# [341]	valid_0's binary_logloss: 0.278306
# [342]	valid_0's binary_logloss: 0.278308
# [343]	valid_0's binary_logloss: 0.278308
# [344]	valid_0's binary_logloss: 0.27831
# [345]	valid_0's binary_logloss: 0.278307
# [346]	valid_0's binary_logloss: 0.278299
# [347]	valid_0's binary_logloss: 0.2783
# [348]	valid_0's binary_logloss: 0.278294
# [349]	valid_0's binary_logloss: 0.279968
# [350]	valid_0's binary_logloss: 0.278688
# [351]	valid_0's binary_logloss: 0.278287
# [352]	valid_0's binary_logloss: 0.27851
# [353]	valid_0's binary_logloss: 0.280218
# [354]	valid_0's binary_logloss: 0.279674
# [355]	valid_0's binary_logloss: 0.278595
# [356]	valid_0's binary_logloss: 0.278537
# [357]	valid_0's binary_logloss: 0.279191
# [358]	valid_0's binary_logloss: 0.27855
# [359]	valid_0's binary_logloss: 0.278511
# [360]	valid_0's binary_logloss: 0.278509
# [361]	valid_0's binary_logloss: 0.278504
# [362]	valid_0's binary_logloss: 0.280175
# [363]	valid_0's binary_logloss: 0.279603
# [364]	valid_0's binary_logloss: 0.279262
# [365]	valid_0's binary_logloss: 0.279264
# [366]	valid_0's binary_logloss: 0.27926
# [367]	valid_0's binary_logloss: 0.279261
# [368]	valid_0's binary_logloss: 0.279262
# [369]	valid_0's binary_logloss: 0.279257
# [370]	valid_0's binary_logloss: 0.279253
# [371]	valid_0's binary_logloss: 0.279252
# [372]	valid_0's binary_logloss: 0.279258
# [373]	valid_0's binary_logloss: 0.279257
# [374]	valid_0's binary_logloss: 0.279259
# [375]	valid_0's binary_logloss: 0.279261
# [376]	valid_0's binary_logloss: 0.279627
# [377]	valid_0's binary_logloss: 0.279414
# [378]	valid_0's binary_logloss: 0.27941
# [379]	valid_0's binary_logloss: 0.279429
# [380]	valid_0's binary_logloss: 0.279449
# [381]	valid_0's binary_logloss: 0.279446
# [382]	valid_0's binary_logloss: 0.279526
# [383]	valid_0's binary_logloss: 0.279444
# [384]	valid_0's binary_logloss: 0.279445
# [385]	valid_0's binary_logloss: 0.279448
# [386]	valid_0's binary_logloss: 0.279516
# [387]	valid_0's binary_logloss: 0.279865
# [388]	valid_0's binary_logloss: 0.279817
# [389]	valid_0's binary_logloss: 0.279818
# [390]	valid_0's binary_logloss: 0.279819
# [391]	valid_0's binary_logloss: 0.279924
# [392]	valid_0's binary_logloss: 0.280166
# [393]	valid_0's binary_logloss: 0.279888
# [394]	valid_0's binary_logloss: 0.280127
# [395]	valid_0's binary_logloss: 0.280566
# [396]	valid_0's binary_logloss: 0.280479
# [397]	valid_0's binary_logloss: 0.280394
# [398]	valid_0's binary_logloss: 0.280536
# [399]	valid_0's binary_logloss: 0.281757
# [400]	valid_0's binary_logloss: 0.280696
# [401]	valid_0's binary_logloss: 0.280702
# [402]	valid_0's binary_logloss: 0.2807
# [403]	valid_0's binary_logloss: 0.280698
# [404]	valid_0's binary_logloss: 0.280699
# [405]	valid_0's binary_logloss: 0.280701
# [406]	valid_0's binary_logloss: 0.281417
# [407]	valid_0's binary_logloss: 0.280696
# [408]	valid_0's binary_logloss: 0.280697
# [409]	valid_0's binary_logloss: 0.280693
# [410]	valid_0's binary_logloss: 0.280694
# [411]	valid_0's binary_logloss: 0.280695
# [412]	valid_0's binary_logloss: 0.280697
# [413]	valid_0's binary_logloss: 0.280698
# [414]	valid_0's binary_logloss: 0.280701
# [415]	valid_0's binary_logloss: 0.280701
# Early stopping, best iteration is:
# [115]	valid_0's binary_logloss: 0.272474
# 1 0.7695969085275665
# [1]	valid_0's binary_logloss: 0.442531
# Training until validation scores don't improve for 300 rounds
# [2]	valid_0's binary_logloss: 0.413964
# [3]	valid_0's binary_logloss: 0.391897
# [4]	valid_0's binary_logloss: 0.374175
# [5]	valid_0's binary_logloss: 0.359687
# [6]	valid_0's binary_logloss: 0.347648
# [7]	valid_0's binary_logloss: 0.337525
# [8]	valid_0's binary_logloss: 0.328991
# [9]	valid_0's binary_logloss: 0.321729
# [10]	valid_0's binary_logloss: 0.315528
# [11]	valid_0's binary_logloss: 0.3102
# [12]	valid_0's binary_logloss: 0.305601
# [13]	valid_0's binary_logloss: 0.301635
# [14]	valid_0's binary_logloss: 0.298199
# [15]	valid_0's binary_logloss: 0.295236
# [16]	valid_0's binary_logloss: 0.292641
# [17]	valid_0's binary_logloss: 0.290368
# [18]	valid_0's binary_logloss: 0.288375
# [19]	valid_0's binary_logloss: 0.28666
# [20]	valid_0's binary_logloss: 0.285139
# [21]	valid_0's binary_logloss: 0.283829
# [22]	valid_0's binary_logloss: 0.282673
# [23]	valid_0's binary_logloss: 0.281669
# [24]	valid_0's binary_logloss: 0.28079
# [25]	valid_0's binary_logloss: 0.28002
# [26]	valid_0's binary_logloss: 0.279348
# [27]	valid_0's binary_logloss: 0.278745
# [28]	valid_0's binary_logloss: 0.278205
# [29]	valid_0's binary_logloss: 0.277722
# [30]	valid_0's binary_logloss: 0.277307
# [31]	valid_0's binary_logloss: 0.276946
# [32]	valid_0's binary_logloss: 0.27662
# [33]	valid_0's binary_logloss: 0.276325
# [34]	valid_0's binary_logloss: 0.276061
# [35]	valid_0's binary_logloss: 0.275821
# [36]	valid_0's binary_logloss: 0.275608
# [37]	valid_0's binary_logloss: 0.275414
# [38]	valid_0's binary_logloss: 0.275245
# [39]	valid_0's binary_logloss: 0.275081
# [40]	valid_0's binary_logloss: 0.274927
# [41]	valid_0's binary_logloss: 0.274812
# [42]	valid_0's binary_logloss: 0.274695
# [43]	valid_0's binary_logloss: 0.274586
# [44]	valid_0's binary_logloss: 0.274489
# [45]	valid_0's binary_logloss: 0.274392
# [46]	valid_0's binary_logloss: 0.274318
# [47]	valid_0's binary_logloss: 0.274257
# [48]	valid_0's binary_logloss: 0.274202
# [49]	valid_0's binary_logloss: 0.274144
# [50]	valid_0's binary_logloss: 0.274091
# [51]	valid_0's binary_logloss: 0.274054
# [52]	valid_0's binary_logloss: 0.27401
# [53]	valid_0's binary_logloss: 0.273971
# [54]	valid_0's binary_logloss: 0.273943
# [55]	valid_0's binary_logloss: 0.273911
# [56]	valid_0's binary_logloss: 0.273865
# [57]	valid_0's binary_logloss: 0.273841
# [58]	valid_0's binary_logloss: 0.273807
# [59]	valid_0's binary_logloss: 0.27381
# [60]	valid_0's binary_logloss: 0.27378
# [61]	valid_0's binary_logloss: 0.273759
# [62]	valid_0's binary_logloss: 0.273772
# [63]	valid_0's binary_logloss: 0.273811
# [64]	valid_0's binary_logloss: 0.273729
# [65]	valid_0's binary_logloss: 0.27372
# [66]	valid_0's binary_logloss: 0.273706
# [67]	valid_0's binary_logloss: 0.273684
# [68]	valid_0's binary_logloss: 0.273679
# [69]	valid_0's binary_logloss: 0.273669
# [70]	valid_0's binary_logloss: 0.273659
# [71]	valid_0's binary_logloss: 0.2737
# [72]	valid_0's binary_logloss: 0.273691
# [73]	valid_0's binary_logloss: 0.273683
# [74]	valid_0's binary_logloss: 0.273702
# [75]	valid_0's binary_logloss: 0.27374
# [76]	valid_0's binary_logloss: 0.273883
# [77]	valid_0's binary_logloss: 0.273797
# [78]	valid_0's binary_logloss: 0.273768
# [79]	valid_0's binary_logloss: 0.273744
# [80]	valid_0's binary_logloss: 0.273727
# [81]	valid_0's binary_logloss: 0.273711
# [82]	valid_0's binary_logloss: 0.273696
# [83]	valid_0's binary_logloss: 0.273684
# [84]	valid_0's binary_logloss: 0.273822
# [85]	valid_0's binary_logloss: 0.273844
# [86]	valid_0's binary_logloss: 0.27376
# [87]	valid_0's binary_logloss: 0.27373
# [88]	valid_0's binary_logloss: 0.27412
# [89]	valid_0's binary_logloss: 0.273731
# [90]	valid_0's binary_logloss: 0.273718
# [91]	valid_0's binary_logloss: 0.273714
# [92]	valid_0's binary_logloss: 0.27371
# [93]	valid_0's binary_logloss: 0.274355
# [94]	valid_0's binary_logloss: 0.27431
# [95]	valid_0's binary_logloss: 0.274682
# [96]	valid_0's binary_logloss: 0.275451
# [97]	valid_0's binary_logloss: 0.275371
# [98]	valid_0's binary_logloss: 0.274592
# [99]	valid_0's binary_logloss: 0.274716
# [100]	valid_0's binary_logloss: 0.274434
# [101]	valid_0's binary_logloss: 0.274431
# [102]	valid_0's binary_logloss: 0.274422
# [103]	valid_0's binary_logloss: 0.274417
# [104]	valid_0's binary_logloss: 0.274407
# [105]	valid_0's binary_logloss: 0.274403
# [106]	valid_0's binary_logloss: 0.274398
# [107]	valid_0's binary_logloss: 0.274391
# [108]	valid_0's binary_logloss: 0.274392
# [109]	valid_0's binary_logloss: 0.274384
# [110]	valid_0's binary_logloss: 0.274373
# [111]	valid_0's binary_logloss: 0.274367
# [112]	valid_0's binary_logloss: 0.274362
# [113]	valid_0's binary_logloss: 0.27435
# [114]	valid_0's binary_logloss: 0.274345
# [115]	valid_0's binary_logloss: 0.274337
# [116]	valid_0's binary_logloss: 0.27434
# [117]	valid_0's binary_logloss: 0.27434
# [118]	valid_0's binary_logloss: 0.274575
# [119]	valid_0's binary_logloss: 0.274332
# [120]	valid_0's binary_logloss: 0.274332
# [121]	valid_0's binary_logloss: 0.274327
# [122]	valid_0's binary_logloss: 0.274325
# [123]	valid_0's binary_logloss: 0.274319
# [124]	valid_0's binary_logloss: 0.274323
# [125]	valid_0's binary_logloss: 0.274319
# [126]	valid_0's binary_logloss: 0.274318
# [127]	valid_0's binary_logloss: 0.274316
# [128]	valid_0's binary_logloss: 0.274318
# [129]	valid_0's binary_logloss: 0.274354
# [130]	valid_0's binary_logloss: 0.274836
# [131]	valid_0's binary_logloss: 0.274857
# [132]	valid_0's binary_logloss: 0.274372
# [133]	valid_0's binary_logloss: 0.275331
# [134]	valid_0's binary_logloss: 0.274457
# [135]	valid_0's binary_logloss: 0.275181
# [136]	valid_0's binary_logloss: 0.274445
# [137]	valid_0's binary_logloss: 0.275165
# [138]	valid_0's binary_logloss: 0.276301
# [139]	valid_0's binary_logloss: 0.275016
# [140]	valid_0's binary_logloss: 0.274614
# [141]	valid_0's binary_logloss: 0.274764
# [142]	valid_0's binary_logloss: 0.2746
# [143]	valid_0's binary_logloss: 0.274596
# [144]	valid_0's binary_logloss: 0.274596
# [145]	valid_0's binary_logloss: 0.275024
# [146]	valid_0's binary_logloss: 0.274964
# [147]	valid_0's binary_logloss: 0.275157
# [148]	valid_0's binary_logloss: 0.275022
# [149]	valid_0's binary_logloss: 0.275611
# [150]	valid_0's binary_logloss: 0.275316
# [151]	valid_0's binary_logloss: 0.276959
# [152]	valid_0's binary_logloss: 0.275992
# [153]	valid_0's binary_logloss: 0.275048
# [154]	valid_0's binary_logloss: 0.275044
# [155]	valid_0's binary_logloss: 0.27504
# [156]	valid_0's binary_logloss: 0.275042
# [157]	valid_0's binary_logloss: 0.275044
# [158]	valid_0's binary_logloss: 0.275043
# [159]	valid_0's binary_logloss: 0.276156
# [160]	valid_0's binary_logloss: 0.275516
# [161]	valid_0's binary_logloss: 0.275362
# [162]	valid_0's binary_logloss: 0.2793
# [163]	valid_0's binary_logloss: 0.275873
# [164]	valid_0's binary_logloss: 0.275215
# [165]	valid_0's binary_logloss: 0.27522
# [166]	valid_0's binary_logloss: 0.275231
# [167]	valid_0's binary_logloss: 0.275233
# [168]	valid_0's binary_logloss: 0.275231
# [169]	valid_0's binary_logloss: 0.275229
# [170]	valid_0's binary_logloss: 0.27523
# [171]	valid_0's binary_logloss: 0.27523
# [172]	valid_0's binary_logloss: 0.275216
# [173]	valid_0's binary_logloss: 0.275215
# [174]	valid_0's binary_logloss: 0.275213
# [175]	valid_0's binary_logloss: 0.275218
# [176]	valid_0's binary_logloss: 0.275599
# [177]	valid_0's binary_logloss: 0.275442
# [178]	valid_0's binary_logloss: 0.275433
# [179]	valid_0's binary_logloss: 0.275435
# [180]	valid_0's binary_logloss: 0.27543
# [181]	valid_0's binary_logloss: 0.27543
# [182]	valid_0's binary_logloss: 0.275432
# [183]	valid_0's binary_logloss: 0.275432
# [184]	valid_0's binary_logloss: 0.276031
# [185]	valid_0's binary_logloss: 0.275434
# [186]	valid_0's binary_logloss: 0.275432
# [187]	valid_0's binary_logloss: 0.27791
# [188]	valid_0's binary_logloss: 0.275506
# [189]	valid_0's binary_logloss: 0.278457
# [190]	valid_0's binary_logloss: 0.275696
# [191]	valid_0's binary_logloss: 0.276946
# [192]	valid_0's binary_logloss: 0.283824
# [193]	valid_0's binary_logloss: 0.276507
# [194]	valid_0's binary_logloss: 0.278207
# [195]	valid_0's binary_logloss: 0.276886
# [196]	valid_0's binary_logloss: 0.278888
# [197]	valid_0's binary_logloss: 0.278236
# [198]	valid_0's binary_logloss: 0.276093
# [199]	valid_0's binary_logloss: 0.27746
# [200]	valid_0's binary_logloss: 0.27644
# [201]	valid_0's binary_logloss: 0.276876
# [202]	valid_0's binary_logloss: 0.276194
# [203]	valid_0's binary_logloss: 0.278556
# [204]	valid_0's binary_logloss: 0.276445
# [205]	valid_0's binary_logloss: 0.277446
# [206]	valid_0's binary_logloss: 0.283285
# [207]	valid_0's binary_logloss: 0.285321
# [208]	valid_0's binary_logloss: 0.276363
# [209]	valid_0's binary_logloss: 0.27635
# [210]	valid_0's binary_logloss: 0.276352
# [211]	valid_0's binary_logloss: 0.276485
# [212]	valid_0's binary_logloss: 0.280003
# [213]	valid_0's binary_logloss: 0.277462
# [214]	valid_0's binary_logloss: 0.276835
# [215]	valid_0's binary_logloss: 0.276691
# [216]	valid_0's binary_logloss: 0.277276
# [217]	valid_0's binary_logloss: 0.276806
# [218]	valid_0's binary_logloss: 0.276667
# [219]	valid_0's binary_logloss: 0.27677
# [220]	valid_0's binary_logloss: 0.285569
# [221]	valid_0's binary_logloss: 0.279565
# [222]	valid_0's binary_logloss: 0.277796
# [223]	valid_0's binary_logloss: 0.277396
# [224]	valid_0's binary_logloss: 0.277486
# [225]	valid_0's binary_logloss: 0.279963
# [226]	valid_0's binary_logloss: 0.277532
# [227]	valid_0's binary_logloss: 0.277453
# [228]	valid_0's binary_logloss: 0.282793
# [229]	valid_0's binary_logloss: 0.27708
# [230]	valid_0's binary_logloss: 0.27702
# [231]	valid_0's binary_logloss: 0.277015
# [232]	valid_0's binary_logloss: 0.277014
# [233]	valid_0's binary_logloss: 0.277017
# [234]	valid_0's binary_logloss: 0.277006
# [235]	valid_0's binary_logloss: 0.277005
# [236]	valid_0's binary_logloss: 0.277006
# [237]	valid_0's binary_logloss: 0.277007
# [238]	valid_0's binary_logloss: 0.277006
# [239]	valid_0's binary_logloss: 0.276999
# [240]	valid_0's binary_logloss: 0.27732
# [241]	valid_0's binary_logloss: 0.27708
# [242]	valid_0's binary_logloss: 0.277081
# [243]	valid_0's binary_logloss: 0.277082
# [244]	valid_0's binary_logloss: 0.279636
# [245]	valid_0's binary_logloss: 0.276915
# [246]	valid_0's binary_logloss: 0.280897
# [247]	valid_0's binary_logloss: 0.277394
# [248]	valid_0's binary_logloss: 0.279589
# [249]	valid_0's binary_logloss: 0.27788
# [250]	valid_0's binary_logloss: 0.277268
# [251]	valid_0's binary_logloss: 0.277266
# [252]	valid_0's binary_logloss: 0.277025
# [253]	valid_0's binary_logloss: 0.277028
# [254]	valid_0's binary_logloss: 0.277028
# [255]	valid_0's binary_logloss: 0.277029
# [256]	valid_0's binary_logloss: 0.279729
# [257]	valid_0's binary_logloss: 0.27696
# [258]	valid_0's binary_logloss: 0.276963
# [259]	valid_0's binary_logloss: 0.276966
# [260]	valid_0's binary_logloss: 0.276887
# [261]	valid_0's binary_logloss: 0.276886
# [262]	valid_0's binary_logloss: 0.276876
# [263]	valid_0's binary_logloss: 0.27687
# [264]	valid_0's binary_logloss: 0.276871
# [265]	valid_0's binary_logloss: 0.276867
# [266]	valid_0's binary_logloss: 0.277427
# [267]	valid_0's binary_logloss: 0.277266
# [268]	valid_0's binary_logloss: 0.277586
# [269]	valid_0's binary_logloss: 0.276864
# [270]	valid_0's binary_logloss: 0.276863
# [271]	valid_0's binary_logloss: 0.276867
# [272]	valid_0's binary_logloss: 0.276868
# [273]	valid_0's binary_logloss: 0.276862
# [274]	valid_0's binary_logloss: 0.276865
# [275]	valid_0's binary_logloss: 0.276865
# [276]	valid_0's binary_logloss: 0.276867
# [277]	valid_0's binary_logloss: 0.276868
# [278]	valid_0's binary_logloss: 0.278771
# [279]	valid_0's binary_logloss: 0.2773
# [280]	valid_0's binary_logloss: 0.277302
# [281]	valid_0's binary_logloss: 0.277294
# [282]	valid_0's binary_logloss: 0.277054
# [283]	valid_0's binary_logloss: 0.277055
# [284]	valid_0's binary_logloss: 0.277051
# [285]	valid_0's binary_logloss: 0.277269
# [286]	valid_0's binary_logloss: 0.277031
# [287]	valid_0's binary_logloss: 0.277137
# [288]	valid_0's binary_logloss: 0.277014
# [289]	valid_0's binary_logloss: 0.282015
# [290]	valid_0's binary_logloss: 0.27763
# [291]	valid_0's binary_logloss: 0.277671
# [292]	valid_0's binary_logloss: 0.278515
# [293]	valid_0's binary_logloss: 0.277868
# [294]	valid_0's binary_logloss: 0.277376
# [295]	valid_0's binary_logloss: 0.277383
# [296]	valid_0's binary_logloss: 0.277376
# [297]	valid_0's binary_logloss: 0.277369
# [298]	valid_0's binary_logloss: 0.277367
# [299]	valid_0's binary_logloss: 0.277455
# [300]	valid_0's binary_logloss: 0.277793
# [301]	valid_0's binary_logloss: 0.277392
# [302]	valid_0's binary_logloss: 0.277405
# [303]	valid_0's binary_logloss: 0.277406
# [304]	valid_0's binary_logloss: 0.277552
# [305]	valid_0's binary_logloss: 0.27855
# [306]	valid_0's binary_logloss: 0.277783
# [307]	valid_0's binary_logloss: 0.278652
# [308]	valid_0's binary_logloss: 0.279061
# [309]	valid_0's binary_logloss: 0.278532
# [310]	valid_0's binary_logloss: 0.277923
# [311]	valid_0's binary_logloss: 0.277843
# [312]	valid_0's binary_logloss: 0.277907
# [313]	valid_0's binary_logloss: 0.277837
# [314]	valid_0's binary_logloss: 0.277835
# [315]	valid_0's binary_logloss: 0.279704
# [316]	valid_0's binary_logloss: 0.278996
# [317]	valid_0's binary_logloss: 0.281554
# [318]	valid_0's binary_logloss: 0.278773
# [319]	valid_0's binary_logloss: 0.278817
# [320]	valid_0's binary_logloss: 0.278505
# [321]	valid_0's binary_logloss: 0.278502
# [322]	valid_0's binary_logloss: 0.27853
# [323]	valid_0's binary_logloss: 0.278526
# [324]	valid_0's binary_logloss: 0.278524
# [325]	valid_0's binary_logloss: 0.278522
# [326]	valid_0's binary_logloss: 0.278522
# [327]	valid_0's binary_logloss: 0.278521
# [328]	valid_0's binary_logloss: 0.278536
# [329]	valid_0's binary_logloss: 0.279815
# [330]	valid_0's binary_logloss: 0.278617
# [331]	valid_0's binary_logloss: 0.278504
# [332]	valid_0's binary_logloss: 0.278505
# [333]	valid_0's binary_logloss: 0.278502
# [334]	valid_0's binary_logloss: 0.28223
# [335]	valid_0's binary_logloss: 0.278757
# [336]	valid_0's binary_logloss: 0.278479
# [337]	valid_0's binary_logloss: 0.278484
# [338]	valid_0's binary_logloss: 0.278472
# [339]	valid_0's binary_logloss: 0.278474
# [340]	valid_0's binary_logloss: 0.278475
# ...
# [407]	valid_0's binary_logloss: 0.282818
# [408]	valid_0's binary_logloss: 0.284008
# [409]	valid_0's binary_logloss: 0.284535
# [410]	valid_0's binary_logloss: 0.286274
# [411]	valid_0's binary_logloss: 0.281641
# [412]	valid_0's binary_logloss: 0.310599
# [413]	valid_0's binary_logloss: 0.285408
# [414]	valid_0's binary_logloss: 0.283242
# [415]	valid_0's binary_logloss: 0.283208
# Early stopping, best iteration is:
# [115]	valid_0's binary_logloss: 0.272479
# 3 0.771453746813668
# [1]	valid_0's binary_logloss: 0.442622
# Training until validation scores don't improve for 300 rounds
# [2]	valid_0's binary_logloss: 0.414165
# [3]	valid_0's binary_logloss: 0.392166
# [4]	valid_0's binary_logloss: 0.374501
# [5]	valid_0's binary_logloss: 0.360047
# [6]	valid_0's binary_logloss: 0.348073
# [7]	valid_0's binary_logloss: 0.338034
# [8]	valid_0's binary_logloss: 0.32954
# [9]	valid_0's binary_logloss: 0.322322
# [10]	valid_0's binary_logloss: 0.316161
# [11]	valid_0's binary_logloss: 0.310885
# [12]	valid_0's binary_logloss: 0.306342
# [13]	valid_0's binary_logloss: 0.302419
# [14]	valid_0's binary_logloss: 0.299036
# [15]	valid_0's binary_logloss: 0.29607
# [16]	valid_0's binary_logloss: 0.293512
# [17]	valid_0's binary_logloss: 0.291305
# [18]	valid_0's binary_logloss: 0.289349
# [19]	valid_0's binary_logloss: 0.287642
# [20]	valid_0's binary_logloss: 0.286145
# [21]	valid_0's binary_logloss: 0.284843
# [22]	valid_0's binary_logloss: 0.283727
# [23]	valid_0's binary_logloss: 0.282747
# [24]	valid_0's binary_logloss: 0.281877
# [25]	valid_0's binary_logloss: 0.281123
# [26]	valid_0's binary_logloss: 0.280466
# [27]	valid_0's binary_logloss: 0.279888
# [28]	valid_0's binary_logloss: 0.279362
# [29]	valid_0's binary_logloss: 0.278896
# [30]	valid_0's binary_logloss: 0.278475
# [31]	valid_0's binary_logloss: 0.278113
# [32]	valid_0's binary_logloss: 0.27779
# [33]	valid_0's binary_logloss: 0.277507
# [34]	valid_0's binary_logloss: 0.277244
# [35]	valid_0's binary_logloss: 0.277019
# [36]	valid_0's binary_logloss: 0.276818
# [37]	valid_0's binary_logloss: 0.276626
# [38]	valid_0's binary_logloss: 0.276459
# [39]	valid_0's binary_logloss: 0.276307
# [40]	valid_0's binary_logloss: 0.276166
# [41]	valid_0's binary_logloss: 0.276053
# [42]	valid_0's binary_logloss: 0.275941
# [43]	valid_0's binary_logloss: 0.275837
# [44]	valid_0's binary_logloss: 0.275748
# [45]	valid_0's binary_logloss: 0.275663
# [46]	valid_0's binary_logloss: 0.27558
# [47]	valid_0's binary_logloss: 0.275517
# [48]	valid_0's binary_logloss: 0.27545
# [49]	valid_0's binary_logloss: 0.275397
# [50]	valid_0's binary_logloss: 0.275348
# [51]	valid_0's binary_logloss: 0.275309
# [52]	valid_0's binary_logloss: 0.275262
# [53]	valid_0's binary_logloss: 0.275218
# [54]	valid_0's binary_logloss: 0.275177
# [55]	valid_0's binary_logloss: 0.275143
# [56]	valid_0's binary_logloss: 0.275112
# [57]	valid_0's binary_logloss: 0.275085
# [58]	valid_0's binary_logloss: 0.275101
# [59]	valid_0's binary_logloss: 0.275181
# [60]	valid_0's binary_logloss: 0.275063
# [61]	valid_0's binary_logloss: 0.275044
# [62]	valid_0's binary_logloss: 0.275015
# [63]	valid_0's binary_logloss: 0.27501
# [64]	valid_0's binary_logloss: 0.274994
# [65]	valid_0's binary_logloss: 0.274985
# [66]	valid_0's binary_logloss: 0.274972
# [67]	valid_0's binary_logloss: 0.274966
# [68]	valid_0's binary_logloss: 0.274957
# [69]	valid_0's binary_logloss: 0.274948
# [70]	valid_0's binary_logloss: 0.274942
# [71]	valid_0's binary_logloss: 0.274936
# [72]	valid_0's binary_logloss: 0.274932
# [73]	valid_0's binary_logloss: 0.274918
# [74]	valid_0's binary_logloss: 0.274905
# [75]	valid_0's binary_logloss: 0.274899
# [76]	valid_0's binary_logloss: 0.274898
# [77]	valid_0's binary_logloss: 0.274887
# [78]	valid_0's binary_logloss: 0.274975
# [79]	valid_0's binary_logloss: 0.274892
# [80]	valid_0's binary_logloss: 0.275249
# [81]	valid_0's binary_logloss: 0.274991
# [82]	valid_0's binary_logloss: 0.27516
# [83]	valid_0's binary_logloss: 0.275184
# [84]	valid_0's binary_logloss: 0.275138
# [85]	valid_0's binary_logloss: 0.275011
# [86]	valid_0's binary_logloss: 0.274989
# [87]	valid_0's binary_logloss: 0.274979
# [88]	valid_0's binary_logloss: 0.274991
# [89]	valid_0's binary_logloss: 0.275079
# [90]	valid_0's binary_logloss: 0.275007
# [91]	valid_0's binary_logloss: 0.275431
# [92]	valid_0's binary_logloss: 0.274998
# [93]	valid_0's binary_logloss: 0.274978
# [94]	valid_0's binary_logloss: 0.275586
# [95]	valid_0's binary_logloss: 0.275026
# [96]	valid_0's binary_logloss: 0.275443
# [97]	valid_0's binary_logloss: 0.276048
# [98]	valid_0's binary_logloss: 0.275586
# [99]	valid_0's binary_logloss: 0.275519
# [100]	valid_0's binary_logloss: 0.275516
# [101]	valid_0's binary_logloss: 0.275507
# [102]	valid_0's binary_logloss: 0.2755
# [103]	valid_0's binary_logloss: 0.275406
# [104]	valid_0's binary_logloss: 0.275426
# [105]	valid_0's binary_logloss: 0.27579
# [106]	valid_0's binary_logloss: 0.275547
# [107]	valid_0's binary_logloss: 0.275868
# [108]	valid_0's binary_logloss: 0.275644
# [109]	valid_0's binary_logloss: 0.275597
# [110]	valid_0's binary_logloss: 0.275583
# [111]	valid_0's binary_logloss: 0.275575
# [112]	valid_0's binary_logloss: 0.275569
# [113]	valid_0's binary_logloss: 0.275559
# [114]	valid_0's binary_logloss: 0.275551
# [115]	valid_0's binary_logloss: 0.276029
# [116]	valid_0's binary_logloss: 0.275654
# [117]	valid_0's binary_logloss: 0.275865
# [118]	valid_0's binary_logloss: 0.275792
# [119]	valid_0's binary_logloss: 0.275821
# [120]	valid_0's binary_logloss: 0.275421
# [121]	valid_0's binary_logloss: 0.275423
# [122]	valid_0's binary_logloss: 0.275418
# [123]	valid_0's binary_logloss: 0.275417
# [124]	valid_0's binary_logloss: 0.275418
# [125]	valid_0's binary_logloss: 0.275522
# [126]	valid_0's binary_logloss: 0.275384
# [127]	valid_0's binary_logloss: 0.275407
# [128]	valid_0's binary_logloss: 0.275503
# [129]	valid_0's binary_logloss: 0.275503
# [130]	valid_0's binary_logloss: 0.275503
# [131]	valid_0's binary_logloss: 0.275432
# [132]	valid_0's binary_logloss: 0.27543
# [133]	valid_0's binary_logloss: 0.275518
# [134]	valid_0's binary_logloss: 0.275418
# [135]	valid_0's binary_logloss: 0.275418
# [136]	valid_0's binary_logloss: 0.276561
# [137]	valid_0's binary_logloss: 0.275361
# [138]	valid_0's binary_logloss: 0.275349
# [139]	valid_0's binary_logloss: 0.275336
# [140]	valid_0's binary_logloss: 0.27535
# [141]	valid_0's binary_logloss: 0.275352
# [142]	valid_0's binary_logloss: 0.27534
# [143]	valid_0's binary_logloss: 0.27534
# [144]	valid_0's binary_logloss: 0.275372
# [145]	valid_0's binary_logloss: 0.276059
# [146]	valid_0's binary_logloss: 0.275688
# [147]	valid_0's binary_logloss: 0.276048
# [148]	valid_0's binary_logloss: 0.276709
# [149]	valid_0's binary_logloss: 0.276031
# [150]	valid_0's binary_logloss: 0.276037
# [151]	valid_0's binary_logloss: 0.275556
# [152]	valid_0's binary_logloss: 0.275535
# [153]	valid_0's binary_logloss: 0.275525
# [154]	valid_0's binary_logloss: 0.275526
# [155]	valid_0's binary_logloss: 0.275527
# [156]	valid_0's binary_logloss: 0.275526
# [157]	valid_0's binary_logloss: 0.277276
# [158]	valid_0's binary_logloss: 0.276631
# [159]	valid_0's binary_logloss: 0.276548
# [160]	valid_0's binary_logloss: 0.277748
# [161]	valid_0's binary_logloss: 0.27643
# [162]	valid_0's binary_logloss: 0.277041
# [163]	valid_0's binary_logloss: 0.276246
# [164]	valid_0's binary_logloss: 0.276244
# [165]	valid_0's binary_logloss: 0.276239
# [166]	valid_0's binary_logloss: 0.276239
# [167]	valid_0's binary_logloss: 0.276233
# [168]	valid_0's binary_logloss: 0.276225
# [169]	valid_0's binary_logloss: 0.276217
# [170]	valid_0's binary_logloss: 0.276214
# [171]	valid_0's binary_logloss: 0.276212
# [172]	valid_0's binary_logloss: 0.2803
# [173]	valid_0's binary_logloss: 0.276809
# [174]	valid_0's binary_logloss: 0.296065
# [175]	valid_0's binary_logloss: 0.276543
# [176]	valid_0's binary_logloss: 0.285935
# [177]	valid_0's binary_logloss: 0.276736
# [178]	valid_0's binary_logloss: 0.276897
# [179]	valid_0's binary_logloss: 0.282673
# [180]	valid_0's binary_logloss: 0.276538
# [181]	valid_0's binary_logloss: 0.276545
# [182]	valid_0's binary_logloss: 0.279286
# [183]	valid_0's binary_logloss: 0.277163
# [184]	valid_0's binary_logloss: 0.277359
# [185]	valid_0's binary_logloss: 0.27719
# [186]	valid_0's binary_logloss: 0.276869
# [187]	valid_0's binary_logloss: 0.276834
# [188]	valid_0's binary_logloss: 0.276832
# [189]	valid_0's binary_logloss: 0.27683
# [190]	valid_0's binary_logloss: 0.276825
# [191]	valid_0's binary_logloss: 0.276822
# [192]	valid_0's binary_logloss: 0.276815
# [193]	valid_0's binary_logloss: 0.276843
# [194]	valid_0's binary_logloss: 0.276843
# [195]	valid_0's binary_logloss: 0.276842
# [196]	valid_0's binary_logloss: 0.276843
# [197]	valid_0's binary_logloss: 0.276839
# [198]	valid_0's binary_logloss: 0.276839
# [199]	valid_0's binary_logloss: 0.276835
# [200]	valid_0's binary_logloss: 0.276829
# [201]	valid_0's binary_logloss: 0.27683
# [202]	valid_0's binary_logloss: 0.276833
# [203]	valid_0's binary_logloss: 0.27683
# [204]	valid_0's binary_logloss: 0.276829
# [205]	valid_0's binary_logloss: 0.276824
# [206]	valid_0's binary_logloss: 0.276826
# [207]	valid_0's binary_logloss: 0.276817
# [208]	valid_0's binary_logloss: 0.276814
# [209]	valid_0's binary_logloss: 0.27681
# [210]	valid_0's binary_logloss: 0.276809
# [211]	valid_0's binary_logloss: 0.276797
# [212]	valid_0's binary_logloss: 0.276792
# [213]	valid_0's binary_logloss: 0.276791
# [214]	valid_0's binary_logloss: 0.27727
# [215]	valid_0's binary_logloss: 0.278491
# [216]	valid_0's binary_logloss: 0.277569
# [217]	valid_0's binary_logloss: 0.280232
# [218]	valid_0's binary_logloss: 0.284822
# [219]	valid_0's binary_logloss: 0.278733
# [220]	valid_0's binary_logloss: 0.277716
# [221]	valid_0's binary_logloss: 0.279447
# [222]	valid_0's binary_logloss: 0.277692
# [223]	valid_0's binary_logloss: 0.278512
# [224]	valid_0's binary_logloss: 0.278016
# [225]	valid_0's binary_logloss: 0.278245
# [226]	valid_0's binary_logloss: 0.278032
# [227]	valid_0's binary_logloss: 0.27805
# [228]	valid_0's binary_logloss: 0.27805
# [229]	valid_0's binary_logloss: 0.278049
# [230]	valid_0's binary_logloss: 0.278046
# [231]	valid_0's binary_logloss: 0.278046
# [232]	valid_0's binary_logloss: 0.278049
# [233]	valid_0's binary_logloss: 0.278334
# [234]	valid_0's binary_logloss: 0.278329
# [235]	valid_0's binary_logloss: 0.278327
# [236]	valid_0's binary_logloss: 0.279288
# [237]	valid_0's binary_logloss: 0.278485
# [238]	valid_0's binary_logloss: 0.278483
# [239]	valid_0's binary_logloss: 0.278484
# [240]	valid_0's binary_logloss: 0.278482
# [241]	valid_0's binary_logloss: 0.278482
# [242]	valid_0's binary_logloss: 0.278483
# [243]	valid_0's binary_logloss: 0.278487
# [244]	valid_0's binary_logloss: 0.27849
# [245]	valid_0's binary_logloss: 0.278489
# [246]	valid_0's binary_logloss: 0.278428
# [247]	valid_0's binary_logloss: 0.278431
# [248]	valid_0's binary_logloss: 0.278431
# [249]	valid_0's binary_logloss: 0.278426
# [250]	valid_0's binary_logloss: 0.278428
# [251]	valid_0's binary_logloss: 0.278428
# [252]	valid_0's binary_logloss: 0.27843
# [253]	valid_0's binary_logloss: 0.279066
# [254]	valid_0's binary_logloss: 0.27889
# [255]	valid_0's binary_logloss: 0.278988
# [256]	valid_0's binary_logloss: 0.279263
# [257]	valid_0's binary_logloss: 0.278943
# [258]	valid_0's binary_logloss: 0.279985
# [259]	valid_0's binary_logloss: 0.278698
# [260]	valid_0's binary_logloss: 0.290675
# [261]	valid_0's binary_logloss: 0.278539
# [262]	valid_0's binary_logloss: 0.279938
# [263]	valid_0's binary_logloss: 0.278806
# [264]	valid_0's binary_logloss: 0.278683
# [265]	valid_0's binary_logloss: 0.278679
# [266]	valid_0's binary_logloss: 0.278629
# [267]	valid_0's binary_logloss: 0.278624
# [268]	valid_0's binary_logloss: 0.278625
# [269]	valid_0's binary_logloss: 0.278624
# [270]	valid_0's binary_logloss: 0.278621
# [271]	valid_0's binary_logloss: 0.28007
# [272]	valid_0's binary_logloss: 0.278787
# [273]	valid_0's binary_logloss: 0.281973
# [274]	valid_0's binary_logloss: 0.279438
# [275]	valid_0's binary_logloss: 0.278877
# [276]	valid_0's binary_logloss: 0.278886
# [277]	valid_0's binary_logloss: 0.278728
# [278]	valid_0's binary_logloss: 0.278731
# [279]	valid_0's binary_logloss: 0.278731
# [280]	valid_0's binary_logloss: 0.278733
# [281]	valid_0's binary_logloss: 0.278734
# [282]	valid_0's binary_logloss: 0.278734
# [283]	valid_0's binary_logloss: 0.280922
# [284]	valid_0's binary_logloss: 0.280039
# [285]	valid_0's binary_logloss: 0.279763
# [286]	valid_0's binary_logloss: 0.27976
# [287]	valid_0's binary_logloss: 0.279268
# [288]	valid_0's binary_logloss: 0.279269
# [289]	valid_0's binary_logloss: 0.279271
# [290]	valid_0's binary_logloss: 0.279272
# [291]	valid_0's binary_logloss: 0.279266
# [292]	valid_0's binary_logloss: 0.279258
# [293]	valid_0's binary_logloss: 0.279255
# [294]	valid_0's binary_logloss: 0.279122
# [295]	valid_0's binary_logloss: 0.27912
# [296]	valid_0's binary_logloss: 0.279119
# [297]	valid_0's binary_logloss: 0.279111
# [298]	valid_0's binary_logloss: 0.27911
# [299]	valid_0's binary_logloss: 0.279112
# [300]	valid_0's binary_logloss: 0.279111
# [301]	valid_0's binary_logloss: 0.279111
# [302]	valid_0's binary_logloss: 0.279115
# [303]	valid_0's binary_logloss: 0.279113
# [304]	valid_0's binary_logloss: 0.279113
# [305]	valid_0's binary_logloss: 0.279994
# [306]	valid_0's binary_logloss: 0.279512
# [307]	valid_0's binary_logloss: 0.279262
# [308]	valid_0's binary_logloss: 0.279591
# [309]	valid_0's binary_logloss: 0.279383
# [310]	valid_0's binary_logloss: 0.282359
# [311]	valid_0's binary_logloss: 0.281374
# [312]	valid_0's binary_logloss: 0.281481
# [313]	valid_0's binary_logloss: 0.279937
# [314]	valid_0's binary_logloss: 0.280415
# [315]	valid_0's binary_logloss: 0.279696
# [316]	valid_0's binary_logloss: 0.283866
# [317]	valid_0's binary_logloss: 0.280501
# [318]	valid_0's binary_logloss: 0.288921
# [319]	valid_0's binary_logloss: 0.282546
# [320]	valid_0's binary_logloss: 0.287928
# [321]	valid_0's binary_logloss: 0.285188
# [322]	valid_0's binary_logloss: 0.283118
# [323]	valid_0's binary_logloss: 0.288018
# [324]	valid_0's binary_logloss: 0.281135
# [325]	valid_0's binary_logloss: 0.280783
# [326]	valid_0's binary_logloss: 0.294986
# [327]	valid_0's binary_logloss: 0.280601
# [328]	valid_0's binary_logloss: 0.280626
# [329]	valid_0's binary_logloss: 0.28124
# [330]	valid_0's binary_logloss: 0.280975
# [331]	valid_0's binary_logloss: 0.282123
# [332]	valid_0's binary_logloss: 0.28097
# [333]	valid_0's binary_logloss: 0.281078
# [334]	valid_0's binary_logloss: 0.284765
# [335]	valid_0's binary_logloss: 0.281141
# [336]	valid_0's binary_logloss: 0.280714
# [337]	valid_0's binary_logloss: 0.28066
# [338]	valid_0's binary_logloss: 0.280638
# [339]	valid_0's binary_logloss: 0.280685
# [340]	valid_0's binary_logloss: 0.283533
# [341]	valid_0's binary_logloss: 0.281016
# [342]	valid_0's binary_logloss: 0.28107
# [343]	valid_0's binary_logloss: 0.281519
# [344]	valid_0's binary_logloss: 0.282431
# [345]	valid_0's binary_logloss: 0.281204
# [346]	valid_0's binary_logloss: 0.28095
# [347]	valid_0's binary_logloss: 0.284103
# [348]	valid_0's binary_logloss: 0.281156
# [349]	valid_0's binary_logloss: 0.28083
# [350]	valid_0's binary_logloss: 0.28081
# [351]	valid_0's binary_logloss: 0.280793
# [352]	valid_0's binary_logloss: 0.280778
# [353]	valid_0's binary_logloss: 0.282608
# [354]	valid_0's binary_logloss: 0.283397
# [355]	valid_0's binary_logloss: 0.280663
# [356]	valid_0's binary_logloss: 0.280862
# [357]	valid_0's binary_logloss: 0.281729
# [358]	valid_0's binary_logloss: 0.280751
# [359]	valid_0's binary_logloss: 0.282413
# [360]	valid_0's binary_logloss: 0.281659
# [361]	valid_0's binary_logloss: 0.281139
# [362]	valid_0's binary_logloss: 0.280902
# [363]	valid_0's binary_logloss: 0.280847
# [364]	valid_0's binary_logloss: 0.281036
# [365]	valid_0's binary_logloss: 0.281109
# [366]	valid_0's binary_logloss: 0.280784
# [367]	valid_0's binary_logloss: 0.284147
# [368]	valid_0's binary_logloss: 0.280882
# [369]	valid_0's binary_logloss: 0.292897
# [370]	valid_0's binary_logloss: 0.282253
# [371]	valid_0's binary_logloss: 0.281068
# [372]	valid_0's binary_logloss: 0.280986
# [373]	valid_0's binary_logloss: 0.280938
# [374]	valid_0's binary_logloss: 0.280934
# [375]	valid_0's binary_logloss: 0.281233
# [376]	valid_0's binary_logloss: 0.283374
# [377]	valid_0's binary_logloss: 0.281935
# Early stopping, best iteration is:
# [77]	valid_0's binary_logloss: 0.274887
# 4 0.7689551737850322
# 0.7696374297117283 0.0010216807303939667

# %%
preds = np.mean(np.column_stack(final_predictions), axis=1)

submission = pd.read_csv('./data/SampleSubmission.csv')
submission.CHURN = preds
submission.to_csv("./data/submission-lgb-5-folds-1000-est-42-rs-TENURE-mapped-REGION-fillna-DAKAR-REG-TEN-OHE-StScaler-num-whole-dataset-fillna-by-mean-TarEncRegTen-invert-folds-optuna.csv", index=False)
